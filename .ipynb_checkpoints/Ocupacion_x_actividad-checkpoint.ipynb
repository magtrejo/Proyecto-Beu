# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Abrimos archivos de datos csv
df = pd.read_csv('../Datos/Poblacion_Ocupada_Actividad_Economica.csv', encoding = "ISO-8859-1", engine='python')
df
# Out:
#          Periodo Entidad_Federativa    Sexo       Grupo_edad  \
# 0       20050301     Aguascalientes  Hombre     15 A 24 AÑOS
# 1       20050301     Aguascalientes  Hombre     15 A 24 AÑOS
# 2       20050301     Aguascalientes  Hombre     15 A 24 AÑOS
# 3       20050301     Aguascalientes  Hombre     15 A 24 AÑOS
# 4       20050301     Aguascalientes  Hombre     15 A 24 AÑOS
# ...          ...                ...     ...              ...
# 183489  20200301           Nacional   Mujer  NO ESPECIFICADO
# 183490  20200301           Nacional   Mujer  NO ESPECIFICADO
# 183491  20200301           Nacional   Mujer  NO ESPECIFICADO
# 183492  20200301           Nacional   Mujer  NO ESPECIFICADO
# 183493  20200301           Nacional   Mujer  NO ESPECIFICADO
#
#                                       Actividad_economica  Numero_personas
# 0       Agricultura, Ganadería, Silvicultura, Caza y P...             4284
# 1               Industria Extractiva y de la Electricidad              179
# ...

# %%
# Ver las dimensiones del Dataframe
df.shape
# Out:
# (183494, 6)

# %%
# Los tipos de datos que contiene
df.dtypes
# Out:
# Periodo                 int64
# Entidad_Federativa     object
# Sexo                   object
# Grupo_edad             object
# Actividad_economica    object
# Numero_personas         int64
# dtype: object

# %%
# Validaciones (Es null)
df.isna()
# Out:
#         Periodo  Entidad_Federativa   Sexo  Grupo_edad  Actividad_economica  \
# 0         False               False  False       False                False
# 1         False               False  False       False                False
# 2         False               False  False       False                False
# 3         False               False  False       False                False
# 4         False               False  False       False                False
# ...         ...                 ...    ...         ...                  ...
# 183489    False               False  False       False                False
# 183490    False               False  False       False                False
# 183491    False               False  False       False                False
# 183492    False               False  False       False                False
# 183493    False               False  False       False                False
#
#         Numero_personas
# 0                 False
# ...

# %% [raw]
# #Después, podemos contar cuántos 'NaNs' existen usando la agregación 'sum', que suma '1' por cada 'True' y '0' por cada 'False:

# %%
df.isna().sum(axis=0)
df.isna().sum()
# Out:
# Periodo                0
# Entidad_Federativa     0
# Sexo                   0
# Grupo_edad             0
# Actividad_economica    0
# Numero_personas        0
# dtype: int64

# %%
df.isna().sum(axis=1)
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 183489    0
# 183490    0
# 183491    0
# 183492    0
# 183493    0
# Length: 183494, dtype: int64

# %%
df.dtypes
# Out:
# Periodo                 int64
# Entidad_Federativa     object
# Sexo                   object
# Grupo_edad             object
# Actividad_economica    object
# Numero_personas         int64
# dtype: object

# %% [raw]
# # Filtra los Datos del 2019 y 2020

# %%
# Tomo el mismo periodo pero del año pasado
df_2019 = df[df['Periodo'] == 20190301]
df_2019.head()
df_2020 = df[df['Periodo'] == 20200301]
df_2020.head()

df_periodos = df[df['Periodo'] > 20190000]
df_periodos.groupby(['Periodo']).sum().sort_values('Numero_personas', ascending = False)
# Quita los periodos restantes 2019
df_periodos = df_periodos.drop(df_periodos[df_periodos['Periodo'] == 20190601].index)
df_periodos = df_periodos.drop(df_periodos[df_periodos['Periodo'] == 20190901].index)
df_periodos = df_periodos.drop(df_periodos[df_periodos['Periodo'] == 20191201].index)
df_periodos.groupby(['Periodo']).sum().sort_values('Numero_personas', ascending = False)
df_periodos
# Out:
#          Periodo Entidad_Federativa    Sexo       Grupo_edad  \
# 161864  20190301     Aguascalientes  Hombre     15 A 24 AÑOS
# 161865  20190301     Aguascalientes  Hombre     15 A 24 AÑOS
# 161866  20190301     Aguascalientes  Hombre     15 A 24 AÑOS
# 161867  20190301     Aguascalientes  Hombre     15 A 24 AÑOS
# 161868  20190301     Aguascalientes  Hombre     15 A 24 AÑOS
# ...          ...                ...     ...              ...
# 183489  20200301           Nacional   Mujer  NO ESPECIFICADO
# 183490  20200301           Nacional   Mujer  NO ESPECIFICADO
# 183491  20200301           Nacional   Mujer  NO ESPECIFICADO
# 183492  20200301           Nacional   Mujer  NO ESPECIFICADO
# 183493  20200301           Nacional   Mujer  NO ESPECIFICADO
#
#                                       Actividad_economica  Numero_personas
# 161864  Agricultura, Ganadería, Silvicultura, Caza y P...             3752
# 161865          Industria Extractiva y de la Electricidad              365
# ...

# %%
# Ordeno de forma descendente los datos y solo considero las 5 primeras entidades
df_periodos.sort_values('Numero_personas',ascending = False).head(5)
# Obtiene df Nacional
df_periodos_nacional = df_periodos[df_periodos['Entidad_Federativa'] == 'Nacional']
# Obtiene df Entidad
df_periodo_entidad = df_periodos.drop(df_periodos[df_periodos['Entidad_Federativa'] == 'Nacional'].index)
df_periodo_entidad
# Out:
#          Periodo Entidad_Federativa    Sexo     Grupo_edad  \
# 161864  20190301     Aguascalientes  Hombre   15 A 24 AÑOS
# 161865  20190301     Aguascalientes  Hombre   15 A 24 AÑOS
# 161866  20190301     Aguascalientes  Hombre   15 A 24 AÑOS
# 161867  20190301     Aguascalientes  Hombre   15 A 24 AÑOS
# 161868  20190301     Aguascalientes  Hombre   15 A 24 AÑOS
# ...          ...                ...     ...            ...
# 176529  20200301          Zacatecas   Mujer  65 AÑOS Y MAS
# 176530  20200301          Zacatecas   Mujer  65 AÑOS Y MAS
# 176531  20200301          Zacatecas   Mujer  65 AÑOS Y MAS
# 176532  20200301          Zacatecas   Mujer  65 AÑOS Y MAS
# 176533  20200301          Zacatecas   Mujer  65 AÑOS Y MAS
#
#                                       Actividad_economica  Numero_personas
# 161864  Agricultura, Ganadería, Silvicultura, Caza y P...             3752
# 161865          Industria Extractiva y de la Electricidad              365
# ...

# %%
#Representación Gráfica de los dos Periodos
df_periodos_gr = df_periodos.groupby(['Periodo']).sum()#.sort_values('Numero_personas', ascending = False)
df_periodos_gr
x_values = df_periodos['Periodo'].unique().tolist()
x_values
y_values = df_periodos_gr['Numero_personas'].unique().tolist()
max(y_values)
len(y_values)

desfase = (0, 0.1)
plt.pie(y_values, labels=['Periodo 2019','Periodo 2020'] ,shadow=True ,explode=desfase ,autopct='%1.1f%%', startangle=90,
       labeldistance=1.1, textprops={'fontsize': 12}) #, wedgeprops = {'linewidth': 6}
plt.legend()
plt.show()
plt.close('all')

# %%
# Análisis de Datos General por Entidades-Periodos 
df_periodos_gr = df_periodo_entidad.groupby(['Entidad_Federativa','Periodo']).sum().sort_values(['Numero_personas'], ascending = False)
# Número de Personas ocupadas por Entidad y Periodo
df_periodos_gr = df_periodos_gr.head(10)
df_periodos_gr
#sns.pairplot(df_periodos_gr)
# Out:
#                              Numero_personas
# Entidad_Federativa Periodo
# Estado de México   20200301          7689225
#                    20190301          7558731
# Ciudad de México   20190301          4246706
#                    20200301          4207307
# Jalisco            20200301          3778375
#                    20190301          3757440
# Veracruz           20200301          3431708
#                    20190301          3265254
# Puebla             20200301          2847348
#                    20190301          2812844

# %%
# Out:
#                               Numero_personas
# Periodo  Entidad_Federativa
# 20190301 Aguascalientes                562439
#          Baja California              1684852
#          Baja California Sur           415868
#          Campeche                      414441
#          Chiapas                      1928575
# ...                                       ...
# 20200301 Tamaulipas                   1646601
#          Tlaxcala                      594706
#          Veracruz                     3431708
#          Yucatán                      1086089
#          Zacatecas                     646456
#
# [64 rows x 1 columns]

# %%
df_periodos.groupby(['Entidad_Federativa','Actividad_economica']).agg({'Numero_personas': ['mean', 'min', 'max']})

# Representación Gráfica del Número de Personas ocupadas por Entidad y Periodo 
#df_periodos_gr.plot(kind="bar")
#plt.figure(figsize=(19,10))
# Out:
#                                                                       Numero_personas  \
#                                                                                  mean
# Entidad_Federativa Actividad_economica
# Aguascalientes     Agricultura, Ganadería, Silvicultura, Caza y Pesca     2870.250000
#                    Comercio                                              13375.250000
#                    Construcción                                           6969.230769
#                    Gobierno y Organismos Internacionales                  3511.277778
#                    Industria Extractiva y de la Electricidad               667.545455
# ...                                                                               ...
# Zacatecas          Restaurantes y Servicios de Alojamiento                4603.312500
#                    Servicios Diversos                                     6630.875000
# ...

# %%
# De la gráfica anterior, filtrar las Enidades que tengan mayor numero de personas ocupadas
#df_periodo_entidad.groupby['Entidad_Federativa'].max().sort_values('Numero_personas', ascending = False)
df_periodo_entidad.groupby(['Entidad_Federativa','Periodo']).sum()['Numero_personas']
df_periodo_entidad_19 = df_periodo_entidad[df_periodo_entidad['Periodo'].isin(['20190301'])]
df_periodo_entidad_19
df_periodo_entidad_20 = df_periodo_entidad[df_periodo_entidad['Periodo'].isin(['20200301'])]
df_periodo_entidad_20
df_periodo_entidad
#df_periodo_entidad.sort_values('Numero_personas', ascending = False)
#df_periodo_entidad_fil = df_periodo_entidad[df_periodo_entidad['Entidad_Federativa'].isin(['Estado de México', 'Ciudad de México', 'Jalisco', 'Veracruz'])]
#df_periodo_entidad_fil

#df_periodos_gr = df_grouped[df_grouped['sport'].isin(['Basketball', 'Volleyball', 'Football', 'Baseball'])]
#df_ball

#df_periodos.groupby(['Entidad_Federativa','Actividad_economica']).agg({'Numero_personas': ['mean', 'min', 'max']})
# Out:
#          Periodo Entidad_Federativa    Sexo     Grupo_edad  \
# 161864  20190301     Aguascalientes  Hombre   15 A 24 AÑOS
# 161865  20190301     Aguascalientes  Hombre   15 A 24 AÑOS
# 161866  20190301     Aguascalientes  Hombre   15 A 24 AÑOS
# 161867  20190301     Aguascalientes  Hombre   15 A 24 AÑOS
# 161868  20190301     Aguascalientes  Hombre   15 A 24 AÑOS
# ...          ...                ...     ...            ...
# 176529  20200301          Zacatecas   Mujer  65 AÑOS Y MAS
# 176530  20200301          Zacatecas   Mujer  65 AÑOS Y MAS
# 176531  20200301          Zacatecas   Mujer  65 AÑOS Y MAS
# 176532  20200301          Zacatecas   Mujer  65 AÑOS Y MAS
# 176533  20200301          Zacatecas   Mujer  65 AÑOS Y MAS
#
#                                       Actividad_economica  Numero_personas
# 161864  Agricultura, Ganadería, Silvicultura, Caza y P...             3752
# 161865          Industria Extractiva y de la Electricidad              365
# ...

# %%
df_periodos_act_gr = df_periodos.groupby(['Actividad_economica','Periodo']).sum()['Numero_personas'].unstack()

df_periodo_entidad.groupby(['Periodo','Entidad_Federativa']).sum().sort_values('Periodo', ascending = True)
df_periodo_entidad_gr = df_periodo_entidad.groupby(['Periodo','Entidad_Federativa']).sum()
df_periodo_entidad_gr

# %%
df_periodos_act_gr.plot(kind="bar")
plt.figure(figsize=(19,10))

# %%
df_201901 = df_2a[df_2a['Periodo'] == 20190301]
df_201901
del df_201901['Periodo']
df_201901
df_201901.groupby(['Entidad_Federativa','Actividad_economica']).mean()
df_201901
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-acf1f4a5a7e7> in <module>
# ----> 1 df_201901 = df_2a[df_2a['Periodo'] == 20190301]
#       2 df_201901
#       3 del df_201901['Periodo']
#       4 df_201901
#       5 df_201901.groupby(['Entidad_Federativa','Actividad_economica']).mean()
#
# NameError: name 'df_2a' is not defined

# %%
df_202001 = df_2a[df_2a['Periodo'] == 20200301]
df_202001
df_202001.groupby(['Entidad_Federativa','Actividad_economica']).mean().sort_values("Numero_personas", ascending = False)
df_202001.groupby(['Entidad_Federativa','Actividad_economica']).agg({'Numero_personas': ['mean', 'min', 'max']})
df_202001.groupby(['Entidad_Federativa']).agg({'Numero_personas': ['mean', 'min', 'max']})
df_202001_edos = df_202001[df_202001['Entidad_Federativa'].str.contains('Ciudad de México') | 
          df_202001['Entidad_Federativa'].str.contains('Estado de México') |
          df_202001['Entidad_Federativa'].str.contains('Jalisco') |
          df_202001['Entidad_Federativa'].str.contains('Nuevo León')]
df_202001_edos
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-e70080c372c9> in <module>
# ----> 1 df_202001 = df_2a[df_2a['Periodo'] == 20200301]
#       2 df_202001
#       3 df_202001.groupby(['Entidad_Federativa','Actividad_economica']).mean().sort_values("Numero_personas", ascending = False)
#       4 df_202001.groupby(['Entidad_Federativa','Actividad_economica']).agg({'Numero_personas': ['mean', 'min', 'max']})
#       5 df_202001.groupby(['Entidad_Federativa']).agg({'Numero_personas': ['mean', 'min', 'max']})
#
# NameError: name 'df_2a' is not defined

# %%
#df_2a[df_201901 & df_202001]
df_202001_edos_grupo = df_202001_edos.groupby(['Entidad_Federativa', 'Sexo']).mean()["Numero_personas"].unstack()
# genera el gráfico:
df_202001_edos_grupo.plot(kind="bar")
plt.tight_layout()  # tip(!)
